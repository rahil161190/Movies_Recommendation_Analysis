# %% [markdown]
# <a href="https://colab.research.google.com/github/rahil161190/Movies_Recommendation_Analysis/blob/main/NetflixBusiness_Casestudy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Q-2 Observations on the shape of data,data types of all the attributes,missing value detection,statistical summary

# %%
df = pd.read_csv('netflix.csv')
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# Above df includes movies and TV show combined

# %%
#shape of data
df.shape
# Out:
# (8807, 12)

# %% [markdown]
# This means dataframe has 8807 unique movies/Tvshows release on Netflix and 12 column attributes

# %%
len(df)
# Out:
# 8807

# %%
#data types of all the attributes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
#missing value detection
np.round((df.isna().sum()/len(df))*100,2)
# Out:
# show_id          0.00
# type             0.00
# title            0.00
# director        29.91
# cast             9.37
# country          9.44
# date_added       0.11
# release_year     0.00
# rating           0.05
# duration         0.03
# listed_in        0.00
# description      0.00
# dtype: float64

# %% [markdown]
# Significant missing values i.e 29% in the directors columns and in cast and country column approx 10% missing values.

# %%
#statistical summary
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# Above df include statistical summary.

# %%
df.describe(include = object)
# Out:
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6173
# unique    8807      2                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
#
#                       cast        country       date_added rating  duration  \
# count                 7982           7976             8797   8803      8804
# unique                7692            748             1767     17       220
# top     David Attenborough  United States  January 1, 2020  TV-MA  1 Season
# freq                    19           2818              109   3207      1793
#
#                            listed_in  \
# count                           8807
# unique                           514
# top     Dramas, International Movies
# freq                             362
#
#                                               description
# ...

# %% [markdown]
# Above df includes non-continous data also

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8807, step=1)

# %%
df.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# # Q-1 Defining Problem Statement and Analysing basic metrics
# Q-1a) Comparison of tv shows vs. movies in terms of proportion?

# %%
df['type'].value_counts(normalize = True)*100
# Out:
# type
# Movie      69.615079
# TV Show    30.384921
# Name: proportion, dtype: float64

# %% [markdown]
# Insights
# *   Majority of release i.e approx 70% are of movies while rest of them are TV shows
# *   List item

# %% [markdown]
# Q-1b) Show the dataframew of movies only?

# %%
df_movies = df.loc[df['type']=='Movie']

# %% [markdown]
# Insights
#
# *   These are movies list dataframe

# %% [markdown]
# Q-1c) Show the dataframe of TV Shows only?

# %%
df_TV = df.loc[df['type']=='TV Show']

# %% [markdown]
# Insights
#
#
# *   These are TVshow list dataframe

# %% [markdown]
# Q-1d) Show the missing value in movies dataframe in %?

# %%
(np.round(df_movies.isna().sum()/len(df_movies),2))*100
# Out:
# show_id         0.0
# type            0.0
# title           0.0
# director        3.0
# cast            8.0
# country         7.0
# date_added      0.0
# release_year    0.0
# rating          0.0
# duration        0.0
# listed_in       0.0
# description     0.0
# dtype: float64

# %% [markdown]
# Insights
#
# *   % of missing values in column of cast and country is around 7-8% in Movies dataframe.

# %% [markdown]
# Q-1e) Show the missing value in Tv Show dataframe in %?

# %%
(np.round(df_TV.isna().sum()/len(df_TV),2))*100
# Out:
# show_id          0.0
# type             0.0
# title            0.0
# director        91.0
# cast            13.0
# country         15.0
# date_added       0.0
# release_year     0.0
# rating           0.0
# duration         0.0
# listed_in        0.0
# description      0.0
# dtype: float64

# %% [markdown]
# Insights
#
# *   % of missing values in TV show dataframe
# *   Majority of missing values are from director column

# %% [markdown]
# Q-1f) Show the country contribution for movies and TVshow on Netflix?

# %%
df_movies_explode= df_movies.copy()

# %%
df_movies_explode['country'] = df_movies_explode['country'].str.split(',')

# %%
df_movies_explode = df_movies_explode.explode('country')

# %%
df_movies_explode['country'] = df_movies_explode['country'].str.strip()

# %%
df_TV_explode = df_TV.copy()

# %%
df_TV_explode['country'] = df_TV_explode['country'].dropna().apply(lambda x:x.split(','))

# %%
df_TV_explode = df_TV_explode.explode('country')

# %%
df_movies_explode
#final
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 7         s8  Movie                           Sankofa
# 7         s8  Movie                           Sankofa
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 7                      Haile Gerima
# 7                      Haile Gerima
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
df_TV_explode
#final
# Out:
#      show_id     type                  title         director  \
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8797   s8798  TV Show              Zak Storm              NaN
# 8797   s8798  TV Show              Zak Storm              NaN
# 8797   s8798  TV Show              Zak Storm              NaN
# 8800   s8801  TV Show     Zindagi Gulzar Hai              NaN
# 8803   s8804  TV Show            Zombie Dumb              NaN
#
#                                                    cast       country  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
# ...

# %%
df_TV_explode['country'].value_counts().head(10)
# Out:
# country
# United States     847
# United Kingdom    246
# Japan             174
# South Korea       164
#  United States     91
# Canada             84
# India              81
# Taiwan             70
# France             64
# Australia          56
# Name: count, dtype: int64

# %%
df_movies_explode['country'].value_counts().head(10)
# Out:
# country
# United States     2752
# India              962
# United Kingdom     534
# Canada             319
# France             303
# Germany            182
# Spain              171
# Japan              119
# China              114
# Mexico             111
# Name: count, dtype: int64

# %% [markdown]
# Insights
#
# *   Majority of movies were released in USA
# *   USA and India are major markets in movies movies for netflix
# *   Majority of tv shows were released in USA.
# *   USA, UK are major markets for netflix in terms of TV Shows

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Modifying dataframe of movies for better analysis and insights.
#
#
# *   Adding two columns 'duration_time and date_added(as datetime format) for better visualisation and analysis.

# %%
df_movies['duration_time'] =df_movies['duration'].dropna().apply(lambda x:x[0:-4]).astype('int')
# Out:
# <ipython-input-27-0e26ca01e69a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movies['duration_time'] =df_movies['duration'].dropna().apply(lambda x:x[0:-4]).astype('int')

# %%
df_movies['date_added_datetime'] = pd.to_datetime(df_movies['date_added'])
# Out:
# <ipython-input-28-7043e577a3c7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movies['date_added_datetime'] = pd.to_datetime(df_movies['date_added'])

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6131 entries, 0 to 8806
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   show_id              6131 non-null   object
#  1   type                 6131 non-null   object
#  2   title                6131 non-null   object
#  3   director             5943 non-null   object
#  4   cast                 5656 non-null   object
#  5   country              5691 non-null   object
#  6   date_added           6131 non-null   object
#  7   release_year         6131 non-null   int64
#  8   rating               6129 non-null   object
#  9   duration             6128 non-null   object
#  10  listed_in            6131 non-null   object
#  11  description          6131 non-null   object
#  12  duration_time        6128 non-null   float64
#  13  date_added_datetime  6131 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1), object(11)
# ...

# %%
df_movies.describe()
# Out:
#        release_year  duration_time            date_added_datetime
# count   6131.000000    6128.000000                           6131
# mean    2013.121514      99.577187  2019-05-07 03:32:47.639863040
# min     1942.000000       3.000000            2008-01-01 00:00:00
# 25%     2012.000000      87.000000            2018-04-01 00:00:00
# 50%     2016.000000      98.000000            2019-06-19 00:00:00
# 75%     2018.000000     114.000000            2020-07-23 12:00:00
# max     2021.000000     312.000000            2021-09-25 00:00:00
# std        9.678169      28.290593                            NaN

# %%
df_movies.describe(include = 'object')
# Out:
#        show_id   type                 title       director  \
# count     6131   6131                  6131           5943
# unique    6131      1                  6131           4354
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
#
#                                                      cast        country  \
# count                                                5656           5691
# unique                                               5445            651
# top     Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...  United States
# freq                                                   13           2058
#
#              date_added rating duration                     listed_in  \
# count              6131   6129     6128                          6131
# unique             1533     17      205                           278
# top     January 1, 2020  TV-MA   90 min  Dramas, International Movies
# ...

# %% [markdown]
# Q-1h) Show the genre contribution in movies dataframe?

# %%
df_1 = df_movies.copy()

# %%
df_1['listed_in'] = df_1['listed_in'].apply(lambda x:x.split(','))

# %%
df_1 = df_1.explode('listed_in')

# %%
df_1['listed_in'] = df_1['listed_in'].str.strip()

# %%
df_1['listed_in'].value_counts().head(5)
# Out:
# listed_in
# International Movies    2752
# Dramas                  2427
# Comedies                1674
# Documentaries            869
# Action & Adventure       859
# Name: count, dtype: int64

# %%
sns.countplot(data= df_1,x ='listed_in',order=df_1['listed_in'].value_counts().index)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Insights
#
# *   Majority of movies are of international movies and dramas
# *   Comedies are also having higher contribution in movies dataframe.

# %% [markdown]
# #df_Movies(Modified)

# %%
df_movies
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %% [markdown]
# Q-1i) Show the genre contribution in TV dataframe?

# %%
df_2 = df_TV.copy()
df_2['listed_in'] = df_2['listed_in'].apply(lambda x:x.split(','))
df_2 = df_2.explode('listed_in')
df_2['listed_in'] = df_2['listed_in'].str.strip()
df_2['listed_in'].value_counts().head(5)
# Out:
# listed_in
# International TV Shows    1351
# TV Dramas                  763
# TV Comedies                581
# Crime TV Shows             470
# Kids' TV                   451
# Name: count, dtype: int64

# %%
sns.countplot(data= df_2,x ='listed_in',order=df_2['listed_in'].value_counts().index)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Insights
#
# *   Majority of TVs show are international.
# *   Dramas are also having higher contribution in TV shows.

# %% [markdown]
# Modifying dataframe of TV shows for better analysis and insights.
#
#
# *   Adding two columns 'Number of season and date_added(as datetime format) for better visualisation and analysis.

# %%
df_TV['Number of season'] = df_TV['duration'].apply(lambda x:x[0:2])
# Out:
# <ipython-input-43-c47a2b6b6533>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_TV['Number of season'] = df_TV['duration'].apply(lambda x:x[0:2])

# %%
df_TV['date_added']=df_TV['date_added'].str.strip()
# Out:
# <ipython-input-44-3e5b81063622>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_TV['date_added']=df_TV['date_added'].str.strip()

# %%
df_TV['date_added_datetime']= pd.to_datetime(df_TV['date_added'])
# Out:
# <ipython-input-45-574c561582c3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_TV['date_added_datetime']= pd.to_datetime(df_TV['date_added'])

# %% [markdown]
# # df_TV(Modified)

# %%
df_TV
# Out:
#      show_id     type                  title         director  \
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V              NaN
# 8796   s8797  TV Show             Yunus Emre              NaN
# 8797   s8798  TV Show              Zak Storm              NaN
# 8800   s8801  TV Show     Zindagi Gulzar Hai              NaN
# 8803   s8804  TV Show            Zombie Dumb              NaN
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %%
df_TV.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2676 entries, 1 to 8803
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   show_id              2676 non-null   object
#  1   type                 2676 non-null   object
#  2   title                2676 non-null   object
#  3   director             230 non-null    object
#  4   cast                 2326 non-null   object
#  5   country              2285 non-null   object
#  6   date_added           2666 non-null   object
#  7   release_year         2676 non-null   int64
#  8   rating               2674 non-null   object
#  9   duration             2676 non-null   object
#  10  listed_in            2676 non-null   object
#  11  description          2676 non-null   object
#  12  Number of season     2676 non-null   object
#  13  date_added_datetime  2666 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(12)
# ...

# %% [markdown]
# Q-1j) How has the number of movies & TV released per year changed over the last 20-30 years?

# %%
#movies
plt.figure(figsize=(8,6))
plt.xlabel("Years",fontsize =12)
plt.ylabel("Number_of_movies",fontsize =12)
sns.countplot(data=df_movies,x=df_movies['date_added_datetime'].dt.year)
plt.xticks(rotation=45)
plt.title("Movies/year",fontsize =15)
# Out:
# Text(0.5, 1.0, 'Movies/year')

# %%
#TVshows
plt.figure(figsize=(8,6))
plt.xlabel("Years",fontsize =12)
plt.ylabel("Number_of_TVShows",fontsize =12)
sns.countplot(data=df_TV,x=df_TV['date_added_datetime'].dt.year)
plt.xticks(rotation=45)
plt.title("TVShoes/year",fontsize =15)
# Out:
# Text(0.5, 1.0, 'TVShoes/year')

# %% [markdown]
# Insights
#
# *   No. of movie releases over the last 3 years i.e 2019-2021 are declining.
# *   No. of movie released were maximum in 2018 year and from 2015 to 2018 sharp rise in movie released was observed.
# *   No of TV show releases are increasing in the recent year, the data of 2021 is as of mid 2021
# *   Maximum TV shows were released in the year 2020.
#
# NOTE: Data for the year 2021 should not be considered because data is till mid 2021 only.

# %% [markdown]
# Q-1k) Does Netflix has more focus on TV Shows than movies in recent years

# %%
plt.figure(figsize=(8,6))
plt.xlabel("Years",fontsize =12)
plt.ylabel("Number_of_TVShows",fontsize =12)
sns.countplot(data=df_TV,x=df_TV['date_added_datetime'].dt.year)
plt.xticks(rotation=45)
plt.title("TVShoes/year",fontsize =15)
# Out:
# Text(0.5, 1.0, 'TVShoes/year')

# %% [markdown]
# Insights
#
# *   Figure shows netflix is focusing more on TV shows.
# *   TV shows year on year increasing on Netflix i.e 2020,2019.
# *   Projection of releases in 2021 will be higher than 2020, this data is already as of mid 2021
#
# NOTE: Data for the year 2021 should not be considered because data is till mid 2021 only.

# %% [markdown]
# Q-1l) What is the best time to launch a TV show and Movies ?

# %%
df_TV['date_added_datetime'].dt.month.value_counts().head(5)
# Out:
# date_added_datetime
# 12.0    266
# 7.0     262
# 9.0     251
# 8.0     236
# 6.0     236
# Name: count, dtype: int64

# %%
df_movies['date_added_datetime'].dt.month.value_counts().head(5)
# Out:
# date_added_datetime
# 7     565
# 4     550
# 12    547
# 1     546
# 10    545
# Name: count, dtype: int64

# %%
sns.countplot(data =df_movies,x=df_movies['date_added_datetime'].dt.month,order =df_movies['date_added_datetime'].dt.month.value_counts().index)
plt.xlabel('Month')
plt.title('Movies')
# Out:
# Text(0.5, 1.0, 'Movies')

# %%
sns.countplot(data =df_TV,x=df_TV['date_added_datetime'].dt.month,order =df_TV['date_added_datetime'].dt.month.value_counts().index)
plt.xlabel('Month')
plt.title('TV')
# Out:
# Text(0.5, 1.0, 'TV')

# %% [markdown]
# Insights
#
# *   Launching of TV shows should be in the december month as most tv shows are released in that month and also because of holidays and new year more people will watch.

# %% [markdown]
# Q-1m) Understanding how much movie duration consumed in different countries ?

# %%
df_3 = df_movies_explode.copy()
df_3 = df_3.reset_index(drop=True)
df_3['duration_time'] = df_3['duration'].dropna().apply(lambda x:x[0:-4]).astype('int')

# %%
df_3.groupby('country')['duration_time'].describe().sort_values('count',ascending = False).head(10)
# Out:
#                  count        mean        std   min    25%    50%     75%  \
# country
# United States   2749.0   93.753729  25.200855   3.0   84.0   94.0  106.00
# India            962.0  125.912682  25.795535  29.0  110.0  126.5  142.00
# United Kingdom   534.0   98.760300  26.288603  15.0   89.0   98.0  112.00
# Canada           319.0   91.150470  22.350747  19.0   85.5   92.0  103.00
# France           303.0  100.973597  19.004164  22.0   91.0   99.0  111.00
# Germany          182.0  103.005495  22.355613  21.0   91.0  101.0  116.75
# Spain            171.0  101.099415  18.446953  25.0   91.0  100.0  110.00
# Japan            119.0   98.848739  28.069719   5.0   88.5   99.0  112.00
# China            114.0  104.456140  15.526820  44.0   94.0  105.0  112.50
# Mexico           111.0   90.603604  26.298385  25.0   78.5   93.0  105.00
#
#                   max
# country
# United States   312.0
# India           228.0
# United Kingdom  224.0
# Canada          158.0
# ...

# %%
df_3['country'].value_counts().index[:3]
# Out:
# Index(['United States', 'India', 'United Kingdom'], dtype='object', name='country')

# %% [markdown]
# Insights
#
# *   USA has mean duration time of movies approx 1 hr and 30mins, whereas in India it is approx 2 hrs.
# *   Uk also has average duration time of 90mins.
# *   75 percentile of movies in india have duration time of less than 142 mins whereas for USA and UK it is 106-112 mins.
# *   Some outliers for USA is having movie time of 312mins and whereas for India it is 228min.

# %% [markdown]
# Q-1n) Understanding how much TV seasons consumed in different countries ?

# %%
df_4 = df_TV_explode.copy()
df_4 = df_4.reset_index(drop=True)
df_4['Number of season'] = df_4['duration'].apply(lambda x:x[0:1]).astype('int')
#df_4['Number of season']

# %%
df_4.groupby('country')['Number of season'].describe().sort_values('count',ascending = False).head(5)
# Out:
#                 count      mean       std  min  25%  50%  75%  max
# country
# United States   847.0  2.180638  1.757578  1.0  1.0  1.0  3.0  9.0
# United Kingdom  246.0  1.808943  1.425741  1.0  1.0  1.0  2.0  9.0
# Japan           174.0  1.568966  1.124279  1.0  1.0  1.0  2.0  9.0
# South Korea     164.0  1.201220  0.588018  1.0  1.0  1.0  1.0  6.0
#  United States   91.0  1.967033  1.394039  1.0  1.0  1.0  2.0  7.0

# %% [markdown]
# Insights
#
# *   75 percentile of TV shows in USA having 3 seasons atleast.
# *   75 percentile of TV shows in India having 1 season only.
# *   75 percentile of movies in Japan is having 2 seasons only.

# %% [markdown]
# Q-1o) Find After how many days the movie will be added to Netflix after the release of
# the movie?

# %%
(df_movies['date_added_datetime'].dt.year - df_movies['release_year']).value_counts().head(10)
# Out:
# 0    1862
# 1    1178
# 2     491
# 3     347
# 4     273
# 5     191
# 6     181
# 8     147
# 7     139
# 9     128
# Name: count, dtype: int64

# %%
(df_TV['date_added_datetime'].dt.year - df_TV['release_year']).value_counts().head(10)
# Out:
# 0.0    1379
# 1.0     407
# 2.0     223
# 3.0     144
# 4.0      94
# 5.0      70
# 6.0      70
# 7.0      48
# 8.0      38
# 9.0      33
# Name: count, dtype: int64

# %% [markdown]
# Insights
#
# *   1st Non visual plot gives for movies and we can say most of the movies released on netflix were in the same year as it was released in cinemas also i.e 1862 number of releases.
# *   2nd Non visual plot gives for TV shows and we can say most of the TV shows released on netflix were in the same year as it was released in cinemas also i.e 1379 number of releases.

# %% [markdown]
# Q-1p). Analysis of actors/directors of different types of shows/movies.

# %%
df_movies['cast'].dropna().apply(lambda x:x.split(',')).explode().value_counts().head(10)
# Out:
# cast
#  Anupam Kher       38
#  Rupa Bhimani      27
#  Om Puri           27
# Shah Rukh Khan     26
#  Boman Irani       25
#  Paresh Rawal      25
#  Julie Tejwani     24
# Akshay Kumar       23
#  Rajesh Kava       21
#  Kareena Kapoor    20
# Name: count, dtype: int64

# %%
df_TV['cast'].dropna().apply(lambda x:x.split(',')).explode().value_counts().head(10)
# Out:
# cast
#  Takahiro Sakurai     24
#  Yuki Kaji            17
#  Junichi Suwabe       17
#  Ai Kayano            17
#  Daisuke Ono          14
# David Attenborough    14
#  Takehito Koyasu      13
#  Yoshimasa Hosoya     13
#  Yuichi Nakamura      13
#  Tomokazu Sugita      12
# Name: count, dtype: int64

# %% [markdown]
# Insights
# Top 10 most frequently appearing cast members.
# *   1st Non visual plot gives for movies and actor who has most movies on netflix is anupam kher.
# *   2nd Non visual plot gives for TV shows and actor who has most Tv shows on netflix is Takahiro Sakurai.

# %%
df_movies['director'].dropna().apply(lambda x:x.split(',')).explode().value_counts().head(10)
# Out:
# director
# Rajiv Chilaka          22
#  Jan Suter             18
# Raúl Campos            18
# Suhas Kadav            16
# Jay Karas              15
# Marcus Raboy           15
# Cathy Garcia-Molina    13
# Jay Chapman            12
# Youssef Chahine        12
# Martin Scorsese        12
# Name: count, dtype: int64

# %%
df_TV['director'].dropna().apply(lambda x:x.split(',')).explode().value_counts().head(10)
# Out:
# director
# Alastair Fothergill       3
# Ken Burns                 3
# Jung-ah Im                2
# Joe Berlinger             2
# Shin Won-ho               2
#  Gautham Vasudev Menon    2
# Hsu Fu-chun               2
# Stan Lathan               2
# Iginio Straffi            2
# Rob Seidenglanz           2
# Name: count, dtype: int64

# %% [markdown]
# Insights
# Top 10 most frequently director releases on netflix.
# *   1st Non visual plot is of movies gives for director who has most movies on netflix is Rajiv Chilaka.
# *   2nd Non visual plot is of TV shows and director who has most tv shows are Alastair Fothergill,Ken Burns i.e 3 , most director has atleast 2 tv shows on netflix.

# %% [markdown]
# # Q-3) Non-Graphical Analysis: Value counts and unique attributes

# %% [markdown]
# Q 3a)- Show the value_counts of rating, country,genre(listed_in),Number of season,duration time?

# %%
df_movies_explode['country'].value_counts().head(10)
# Out:
# country
# United States     2752
# India              962
# United Kingdom     534
# Canada             319
# France             303
# Germany            182
# Spain              171
# Japan              119
# China              114
# Mexico             111
# Name: count, dtype: int64

# %%
df_TV_explode['country'].value_counts().head(10)
# Out:
# country
# United States     847
# United Kingdom    246
# Japan             174
# South Korea       164
#  United States     91
# Canada             84
# India              81
# Taiwan             70
# France             64
# Australia          56
# Name: count, dtype: int64

# %% [markdown]
# Insights -
#
# 1.   Above non graphical tables are of  no. of movies/TV released in different countries.
# 1.   USA holds the majority of market

# %%
df_movies['rating'].value_counts().head(10)
# Out:
# rating
# TV-MA    2062
# TV-14    1427
# R         797
# TV-PG     540
# PG-13     490
# PG        287
# TV-Y7     139
# TV-Y      131
# TV-G      126
# NR         75
# Name: count, dtype: int64

# %%
df_TV['rating'].value_counts().head(10)
# Out:
# rating
# TV-MA       1145
# TV-14        733
# TV-PG        323
# TV-Y7        195
# TV-Y         176
# TV-G          94
# NR             5
# R              2
# TV-Y7-FV       1
# Name: count, dtype: int64

# %% [markdown]
# Insights -
#
# 1.   Above non graphical tables are of rating criteria.
# 2.   Movies/Shows released as TV-MA rating are major. TV-MA stands for mature audience

# %%
df_1['listed_in'].value_counts().head(5)
# Movies
# Out:
# listed_in
# International Movies    2752
# Dramas                  2427
# Comedies                1674
# Documentaries            869
# Action & Adventure       859
# Name: count, dtype: int64

# %%
df_2['listed_in'].value_counts().head(5)
#tv Shows
# Out:
# listed_in
# International TV Shows    1351
# TV Dramas                  763
# TV Comedies                581
# Crime TV Shows             470
# Kids' TV                   451
# Name: count, dtype: int64

# %% [markdown]
# Insights -
#
# 1.   Above non graphical tables are of Genre(listed_in column).
# 2.   Movies released as an'International and dramas' genre are much higher than rest of the others.
# 2.   TV Shows released as an'International TV shows' genre are much higher than rest of the others.

# %%
df_TV['Number of season'].value_counts()
#TVShows
# Out:
# Number of season
# 1     1793
# 2      425
# 3      199
# 4       95
# 5       65
# 6       33
# 7       23
# 8       17
# 9        9
# 10       7
# 13       3
# 15       2
# 12       2
# 11       2
# 17       1
# Name: count, dtype: int64

# %%
df_movies['duration_time'].value_counts()
#Movies
# Out:
# duration_time
# 90.0     152
# 94.0     146
# 93.0     146
# 97.0     146
# 91.0     144
#         ...
# 212.0      1
# 8.0        1
# 186.0      1
# 193.0      1
# 191.0      1
# Name: count, Length: 205, dtype: int64

# %% [markdown]
# Insights -
#
# 1.   Most number of TV shows released on Netflix released has 1 season.
# 2.   Mostly Movies released on netflix are of duration 90- 100 minutes.
# 3.   Some outliers are also having season for more than 9 for TV shows.
# 4.   Lesser shows were released having season of 4 or more.
# 5.   Some outliers in movies are having duration of approv 200min also.

# %% [markdown]
# # Q-5. Missing Value & Outlier check (Treatment optional) (10 Points)

# %%
df_movies.isna().sum()
# Out:
# show_id                  0
# type                     0
# title                    0
# director               188
# cast                   475
# country                440
# date_added               0
# release_year             0
# rating                   2
# duration                 3
# listed_in                0
# description              0
# duration_time            3
# date_added_datetime      0
# dtype: int64

# %%
df_TV.isna().sum()
# Out:
# show_id                   0
# type                      0
# title                     0
# director               2446
# cast                    350
# country                 391
# date_added               10
# release_year              0
# rating                    2
# duration                  0
# listed_in                 0
# description               0
# Number of season          0
# date_added_datetime      10
# dtype: int64

# %% [markdown]
# Insights -
#
#
# *   These are number of rows missing in those columns.
# *   For movies missing values are in the column 'cast','country','director'.
# *   For TV shows missing values in the column 'director', 'cast','country'.

# %%
# we can fill this missing values of categorical data with NA(not available) or 0(for continous data)
df_movies['cast'].fillna('NA').isna().sum()
# Out:
# 0

# %%
df_movies['country'].fillna('NA').isna().sum()
# Out:
# 0

# %%
df_movies['director'].fillna('NA').isna().sum()
# Out:
# 0

# %%
df_movies['rating'].fillna('NA').isna().sum()
# Out:
# 0

# %%
df_movies['duration'].fillna(0).isna().sum()
# Out:
# 0

# %%
df_TV['cast'].fillna('NA').isna().sum()
# Out:
# 0

# %%
df_TV['country'].fillna('NA').isna().sum()
# Out:
# 0

# %%
df_TV['director'].fillna('NA').isna().sum()
# Out:
# 0

# %%
df_TV['rating'].fillna('NA').isna().sum()
# Out:
# 0

# %%
df_TV['date_added'].fillna('NA').isna().sum()
# Out:
# 0

# %% [markdown]
# Treatment:
#
#
# *   We have filled missing values with NA(not available) since these are mostly categorical data.
# *   We have filled missing values with 0 for duration column because this contionous variable.

# %% [markdown]
# #  Q-4 Visual Analysis - Univariate, Bivariate after pre-processing of the data
#
# Note: Pre-processing involves unnesting of the data in columns like Actor, Director, Country

# %% [markdown]
# Q 4a)- For continuous variable(s): Distplot, countplot, histogram for univariate analysis?

# %%
top4_country = df_4['country'].value_counts().index[:4]
top4_country
#tv shows data
# Out:
# Index(['United States', 'United Kingdom', 'Japan', 'South Korea'], dtype='object', name='country')

# %%
top4_country_df = df_4.loc[df_4['country'].isin(top4_country)]
#tv shows data

# %%
top5_country= df_3['country'].value_counts().index[:5]
#movie data

# %%
top5_country_df = df_3.loc[df_3['country'].isin(top5_country)]
#movie data

# %% [markdown]
# Q 4b)-  countplot for univariate analysis?

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=top5_country_df,x='country')
plt.xticks(rotation = 90)
plt.title("Movies")
plt.show()

# %% [markdown]
# Insights:
#
#
# *   This is countplot for univariate analysis (categories as country) for Movies.
# *   This are top 5 countries by number of movie releases.
#
# *   USA releases most movies and then India in second.

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=top4_country_df,x='country')
plt.xticks(rotation = 90)
plt.title("TV Shows")
plt.show()

# %% [markdown]
# Insights:
#
# *   This are top 4 countries by number of TV show releases.
# *   This is countplot for univariate analysis (categories as country) for TV shows.
# *   USA releases most TV shows.

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=top5_country_df,x='rating')
plt.xticks(rotation = 90)
plt.title("Movies")
plt.show()

# %% [markdown]
# Insights:
#
# Analysis is done on top 5 countries(number of movie releases).
#
# *   This is countplot for univariate analysis (categories as rating) for movies.
# *   Movie released under rating TV -MA(mature audience) are much higher

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=top4_country_df,x='rating')
plt.xticks(rotation = 90)
plt.title("TV Shows")
plt.show()

# %% [markdown]
# Insights:
#
# Analysis is done on top 4 countries(number of TV shows releases).
# *   This is countplot for univariate analysis (categories as rating) for TV Shows.
# *   TV shows released under rating TV -MA(mature audience) are much higher.

# %% [markdown]
# Q 4c)- histogram for univariate analysis?

# %%
dummy_movie = pd.DataFrame(df_movies['date_added_datetime'].dt.year)

# %%
dummy_tv = pd.DataFrame(df_TV['date_added_datetime'].dt.year)

# %%
dummy_tv['date_added_datetime'].min(),dummy_tv['date_added_datetime'].max()
# Out:
# (2008.0, 2021.0)

# %%
dummy_movie['date_added_datetime'].min(),dummy_movie['date_added_datetime'].max()
# Out:
# (2008, 2021)

# %%
sns.histplot(dummy_movie['date_added_datetime'],bins =14)
plt.xlabel("Year")
plt.title("Movies")
plt.show()

# %%
sns.histplot(dummy_tv['date_added_datetime'],bins =14)
plt.title("TV Shows")
plt.xlabel('Year')
plt.show()

# %% [markdown]
# Insights:
#
# This is histogram graph ,it is a frequency vs range graph.
# *   Frequency in releasing movie from the last couple of years are dropping as we can see in the histogram plot.
# *   Frequency in releasing TV shows from the last couple of years are rising as we can see in the histogram plot.
#
# NOTE: Data for the year 2021 should not be considered because data is till mid 2021 only.

# %% [markdown]
# Q 4d-) For categorical variable(s): Dodged countplot
#
# Releases of movies/tvshows for countries wrt to year ?

# %%
dum_mo = df_movies.loc[df_movies['country'].isin(top5_country)]

# %%
dum_tv = df_TV.loc[df_TV['country'].isin(top4_country)]

# %%
dum_tv['year'] = dum_tv['date_added_datetime'].dt.year
# Out:
# <ipython-input-118-e80d047e5e50>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dum_tv['year'] = dum_tv['date_added_datetime'].dt.year

# %%
dum_mo['year'] = dum_mo['date_added_datetime'].dt.year
# Out:
# <ipython-input-119-b7287bc74978>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dum_mo['year'] = dum_mo['date_added_datetime'].dt.year

# %%
plt.figure(figsize=(20,8))
sns.countplot(x='year',hue='country',data=dum_mo)
plt.title('Movies',fontsize=20)
plt.ylabel('Number of releases',fontsize=15)
plt.xlabel('Year',fontsize=15)
plt.show()

# %%
plt.figure(figsize=(20,8))
sns.countplot(x='year',hue='country',data=dum_tv)
plt.title('Tv Shows',fontsize=20)
plt.ylabel('Number of releases',fontsize=15)
plt.xlabel('Year',fontsize=15)
plt.show()

# %% [markdown]
# Insights:
# This analysis is done focusing top 5 country(based on release on netflix).
#
# *   We can see in the movies graph that no. of releases in the year 2020 were dropped signicantly as compare to 2019.
# *   We can see in the TV shows graph that no. of releases in the year 2019  and 2020 were higher as compare to their previous year.
# *   There is a slight decrease in release for UK TV shows in the year 2020 as compare to 2021
#
# NOTE: Data for the year 2021 should not be considered because data is till mid 2021 only.

# %% [markdown]
# Q 4e-)  For categorical variable(s): Dodged countplot
#
# Releases of ratings of movies/TVshow wrt to year

# %%
dum_mo_rating = dum_mo.loc[dum_mo['rating'].isin(dum_mo['rating'].value_counts().index[:4])]

# %%
dum_mo_rating2 = dum_mo_rating.loc[(dum_mo_rating['year'] == 2017)|(dum_mo_rating['year'] == 2018)| (dum_mo_rating['year'] == 2019) | (dum_mo_rating['year'] == 2020)]

# %%
dum_tv_rating = dum_tv.loc[dum_tv['rating'].isin(dum_tv['rating'].value_counts().index[:4])]

# %%
dum_tv_rating2 = dum_tv_rating.loc[(dum_tv_rating['year'] == 2017)|(dum_tv_rating['year'] == 2018)| (dum_tv_rating['year'] == 2019) | (dum_tv_rating['year'] == 2020)]

# %%
plt.figure(figsize=(20,8))
sns.countplot(x='year',hue='rating',data=dum_mo_rating2)
plt.title('Movies',fontsize=20)
plt.ylabel('Number of releases',fontsize=15)
plt.xlabel('Year',fontsize=15)
plt.show()

# %%
plt.figure(figsize=(20,8))
sns.countplot(x='year',hue='rating',data=dum_tv_rating2)
plt.title('TV Shows',fontsize=20)
plt.ylabel('Number of releases',fontsize=15)
plt.xlabel('Year',fontsize=15)
plt.show()

# %% [markdown]
# Insights:
# This analysis is done focusing top 5 country(based on number of release on netflix). In this we are focusing after 2017 year only.
#
# *   Releases for rating TV -14 is reducing year by year for movie graph.
# *   R and TV MA releases are rising over the recent years for the movie graph.
# *   TV MA releases for TV shows are rising sharply over the recent years, whereas TV PG is reduced for the year 2020 as compare to 2019.
#
# TV MA :- Mature audience
# R     :- Restriced
# TV PG :- Parental Guidance
#
# NOTE: Data for the year 2021 should not be considered because data is till mid 2021 only.

# %% [markdown]
# Q 4f-) For categorical variable(s): Box plot
#
# Movie duration/TV Seasons consumed in top 3 countries(in terms of releases)

# %%
plt.figure(figsize=(10,8))
plt.title('Movies',fontsize =15)
sns.boxplot(x='country', y='duration_time',data=df_3.loc[(df_3['country']=='United States')|(df_3['country']=='India')|(df_3['country']=='United Kingdom')])
# Out:
# <Axes: title={'center': 'Movies'}, xlabel='country', ylabel='duration_time'>

# %%
plt.figure(figsize=(10,8))
plt.title('TV Shows',fontsize =15)
sns.boxplot(x='country', y='Number of season',data=df_4.loc[(df_4['country']=='United States')|(df_4['country']=='United Kingdom')|(df_4['country']=='Japan')])
# Out:
# <Axes: title={'center': 'TV Shows'}, xlabel='country', ylabel='Number of season'>

# %% [markdown]
# Insights:
# This analysis is done focusing top 3 country(based on number of release on netflix).
#
# *   Movies:- Mean duration time of USA and UK is almost same i.e 90-100minutes.
# *   In india mean duration time is approx 120 minutes.
# *   75 percentile for USA UK are under 120minutes only,where as for India 75 percentile movies are under 140minutes.
# *   Tv Shows :- 75% percentile Tv shows of USA has 3 seasons, whereas in UK it is 2 seasons and same for japan.

# %% [markdown]
# Q 4g-)  For categorical variable(s): Dodged countplot
#
# Trends in in genres of movies/TVshow wrt to year

# %%
df_1['listed_in'].value_counts().index[:3]
# Out:
# Index(['International Movies', 'Dramas', 'Comedies'], dtype='object', name='listed_in')

# %%
df_2['listed_in'].value_counts().index[:5]
# Out:
# Index(['International TV Shows', 'TV Dramas', 'TV Comedies', 'Crime TV Shows',
#        'Kids' TV'],
#       dtype='object', name='listed_in')

# %%
new_df = df_1.loc[df_1['listed_in'].isin(df_1['listed_in'].value_counts().index[:5])]
new_df['year'] = new_df['date_added_datetime'].dt.year
new_df = new_df.loc[(new_df['year']==2017)|(new_df['year']==2018)|(new_df['year']==2019)|(new_df['year']==2020)]
new_df.head(5)
# Out:
# <ipython-input-168-5cfe9bcf48d9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['year'] = new_df['date_added_datetime'].dt.year
#      show_id   type             title         director  \
# 1470   s1471  Movie  Alaska Is a Drag     Shaz Bennett
# 1472   s1473  Movie      Bobby Jasoos     Samar Shaikh
# 1472   s1473  Movie      Bobby Jasoos     Samar Shaikh
# 1472   s1473  Movie      Bobby Jasoos     Samar Shaikh
# 1474   s1475  Movie     Tarung Sarung  Archie Hekagery
#
#                                                    cast        country  \
# 1470  Martin L. Washington Jr., Maya Washington, Mat...  United States
# 1472  Vidya Balan, Ali Fazal, Supriya Pathak, Tanvi ...          India
# ...

# %%
new_df_2 = df_2.copy()

# %%
new_df_2['date_added'] = new_df_2['date_added'].str.strip()

# %%
new_df_2['date_added_datetime'] = pd.to_datetime(new_df_2['date_added'])

# %%
new_df_2['year'] = new_df_2['date_added_datetime'].dt.year

# %%
new_df_2.head(2)
# Out:
#   show_id     type          title director  \
# 1      s2  TV Show  Blood & Water      NaN
# 1      s2  TV Show  Blood & Water      NaN
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
#
#            date_added  release_year rating   duration               listed_in  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons  International TV Shows
# 1  September 24, 2021          2021  TV-MA  2 Seasons               TV Dramas
#
#                                          description date_added_datetime  \
# 1  After crossing paths at a party, a Cape Town t...          2021-09-24
# 1  After crossing paths at a party, a Cape Town t...          2021-09-24
#
#      year
# 1  2021.0
# 1  2021.0

# %%
new_df_2 = new_df_2.loc[new_df_2['listed_in'].isin(new_df_2['listed_in'].value_counts().index[:5])]
new_df_2 = new_df_2.loc[(new_df_2['year']==2017)|(new_df_2['year']==2018)|(new_df_2['year']==2019)|(new_df_2['year']==2020)]
new_df_2
# Out:
#      show_id     type                      title        director  \
# 1477   s1478  TV Show                    Dare Me             NaN
# 1477   s1478  TV Show                    Dare Me             NaN
# 1478   s1479  TV Show                    Equinox             NaN
# 1479   s1480  TV Show  SanPa: Sins of the Savior  Cosima Spender
# 1479   s1480  TV Show  SanPa: Sins of the Savior  Cosima Spender
# ...      ...      ...                        ...             ...
# 8796   s8797  TV Show                 Yunus Emre             NaN
# 8796   s8797  TV Show                 Yunus Emre             NaN
# 8797   s8798  TV Show                  Zak Storm             NaN
# 8803   s8804  TV Show                Zombie Dumb             NaN
# 8803   s8804  TV Show                Zombie Dumb             NaN
#
#                                                    cast  \
# 1477  Willa Fitzgerald, Herizen Guardiola, Marlo Kel...
# 1477  Willa Fitzgerald, Herizen Guardiola, Marlo Kel...
# ...

# %%
plt.figure(figsize=(12,8))
plt.title('Movies',fontsize=20)
plt.ylabel('Number of releases',fontsize=15)
sns.countplot(x='year',hue='listed_in',data= new_df)
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.title('TV Shows',fontsize=20)
plt.ylabel('Number of releases',fontsize=15)
sns.countplot(x='year',hue='listed_in',data= new_df_2 )
plt.show()

# %% [markdown]
# Insights:
# This analysis is done focusing top 5 Genre(based on number of release on netflix). Analysis is done after the year 2017 only because of more TV show releases after that time.
#
# *   Movies:- International movies genre are declining.
# *   Comedies genre and kids genre are rising.
# *   TV Dramas trend remains the same.
# *   Documentary genre has as slight decline.
# *   Tv Shows :- Internation TV shows genre are declining.
# *   Previously we saw number of TV shows releases have risen for the year 2020 compare to 2019 overall but after seeing this graph we can say that in 2020 year more different genres are taking a part.
# *   Kids and Comedies genre are rising slightly.

# %% [markdown]
# # Q-6. Insights based on Non-Graphical and Visual Analysis
# 6.1 Comments on the range of attributes
# 6.2 Comments on the distribution of the variables and relationship between them
# 6.3 Comments for each univariate and bivariate plo

# %% [markdown]
# Ans-) All the comments and insights are written on visual plots and non graphical tables above shown. Please refer those points.

# %% [markdown]
# # Q-7. Business Insights - Should include patterns observed in the data along with what you can infer from it

# %% [markdown]
# Ans-)
# 1.   Around 70% releases are of movie type and 30% is Tv shows.
# 1.   Number of releases on netflix are increasing YoY(year on year), but number of movie releases are declining a bit but Tv shows are increasing YoY.
# 1.   USA holds the major marktet for netflix, it has most number of releases for movies and tv show and they are increasing YoY.
# 1.   International movies/ TV dramas are having the most content on netflix till mid 2021, but we can find documentary genre releases are decreasing YoY.
# 1.   For TV shows we can get the insights as releases are of diverse genre i.e not to 1 or 2 specific genre.
# 6.   Tv shows releases over the last 2 years are having regional content i.e regional genre and we can see by the graph that international tv shows are declining.
# 7.   Tv documentary releases are rising YoY.
# 8.   Most number of release of TV shows are having 1-2 seasons.

# %% [markdown]
# # Q-8. Recommendations- Actionable items for business.

# %% [markdown]
# Ans-)
# 1. Netflix should focus more on TV shows has these are gaining popularity among the countries and content available on netflix is only 30% of total.
# 2. Netflix should focus on country content or regional content more to diversify from international content.
# 3. India,Japan,UK,South korea are the market netflix should focus on.
# 4. Most optimum time of movies should be of 80-120 min movies and netflix should should not consider movies which are above 300min as these are all outliers.
# 5. Netflix should focus on comedy & kids content as these are rising globally.
# 6.  Netflix should focus or advertise more for TV shows for those which are not long enough(i.e not more than 3 season) because in todays time shorter format is spreading faster.
# 7.   Netflix should produce more content of rating under PG (parental guidance) as it cater to kids also.
# 8.   Netflix should prioritize of releasing on netflix of the same year of the global release. This way content stays updated and latest trend can be seen.
# Netflix should release movies/tv on holidays or long weekend for much higher viewership.
